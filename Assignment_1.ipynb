# %%
from collections import Counter

with open(r"/content/sample_data/example.txt", "r") as file:
    content = file.read()

word_counter = Counter(content.split())

output = "\n".join("{}\t{}".format(word, count) for word, count in word_counter.items())

with open('/content/sample_data/file.txt', 'w') as file:
    file.write(output)

# %%
def convert(i):
    return i * 2.54

def main():
    n = int(input("Enter the size of the list: "))


    print("Enter the height in inches:")
    i = [float(input()) for _ in range(n)]


    c = [convert(h) for h in i]


    print("\nHeights in inches:")
    for h in i:
        print(f"{h:.2f} i")


    print("\nHeights in centimeters:")
    for cm in c:
        print(f"{cm:.2f} cm")


if __name__ == "__main__":
    main()
# Out:
# Enter the size of the list: 3
# Enter the height in inches:
# 5
# 10
# 15
#
# Heights in inches:
# 5.00 i
# 10.00 i
# 15.00 i
#
# Heights in centimeters:
# 12.70 cm
# 25.40 cm
# 38.10 cm

# %%
def convert(i):
    return i * 2.54

def main():

    n = int(input("Enter the size of the list: "))


    inches = []

    print("Enter the heights in inches:")
    for _ in range(n):
        h = float(input())
        inches.append(h)

    c = [0] * len(inches)

    print("\nHeights in inches:")

    for i in range(len(inches)):
        for _ in range(1):
            c[i] = convert(inches[i])
            print(f"{inches[i]:.2f} i")

    print("\nHeights in centimeters:")
    for cm in c:
        print(f"{cm:.2f} cm")


if __name__ == "__main__":
    main()
# Out:
# Enter the size of the list: 3
# Enter the heights in inches:
# 5
# 10
# 15
#
# Heights in inches:
# 5.00 i
# 10.00 i
# 15.00 i
#
# Heights in centimeters:
# 12.70 cm
# 25.40 cm
# 38.10 cm

# %%
def fullname(first_name, last_name):

    return f"{first_name} {last_name}"

def string_alternative(full_name):

    return full_name[::2]

def main():
    first_name = input("Enter your first name: ")
    last_name = input("Enter your last name: ")
    full_name = fullname(first_name, last_name)
    print("Full name:", full_name)
    alternative_string = string_alternative(full_name)

    print("Every other character in the full name:", alternative_string)


if __name__ == "__main__":
    main()
# Out:
# Enter your first name: Sai
# Enter your last name: Krishna
# Full name: Sai Krishna
# Every other character in the full name: SiKiha
